# %%
from finance.data.asset_profile import collect_and_store_asset_profiles
from finance.data.db.schema import sync_table_schema, NYSE_SCHEMAS
from finance.data.db.mysql import MySQLClient
from finance.sample import portfolio_sample


# fails = collect_and_store_asset_profiles(
#     kinds= ["etf"],
#     chunk_size=50,      # 처음엔 20~50 추천
#     sleep=0.5,          # rate limit 방지
#     max_retry=3,
#     host="localhost",
#     user="root",
#     password="1234",
#     port=3306,
#     save_fail_csv=True,
#     csv_dir="csv",
# )

portfolio_sample()
# print("hello")
# Out:
# [*********************100%***********************]  4 of 4 completed
# [*********************100%***********************]  12 of 12 completed
#          Date        End Ticker       Next Ticker  \
# 0  2016-01-29               NaN        [IEF, TLT]
# 1  2016-03-31        [IEF, TLT]  [VNQ, GLD, MTUM]
# 2  2016-05-31  [VNQ, GLD, MTUM]  [VNQ, TLT, MTUM]
# 3  2016-07-29  [VNQ, TLT, MTUM]   [VNQ, GLD, TLT]
# 4  2016-09-30   [VNQ, GLD, TLT]   [IWN, IWM, IWD]
# ..        ...               ...               ...
# 57 2025-07-31  [GLD, MTUM, EFA]  [MTUM, GLD, SPY]
# 58 2025-09-30  [MTUM, GLD, SPY]  [GLD, MTUM, SPY]
# 59 2025-11-28  [GLD, MTUM, SPY]   [GLD, EFA, SPY]
# 60 2026-01-30   [GLD, EFA, SPY]   [GLD, EFA, IWN]
# 61 2026-02-11   [GLD, EFA, IWN]   [GLD, EFA, IWN]
#
#                     End Balance                 Next Balance  Cash  \
# 0                     [0, 0, 0]             [3333.3, 3333.3]  3333
# 1              [3380.6, 3433.0]     [3382.3, 3382.3, 3382.3]     0
# 2      [3377.1, 3336.9, 3443.4]     [3385.8, 3385.8, 3385.8]     0
# 3      [3774.7, 3696.7, 3579.3]     [3683.6, 3683.6, 3683.6]     0
# 4      [3480.0, 3588.2, 3591.3]     [3553.2, 3553.2, 3553.2]     0
# ..                          ...                          ...   ...
# 57     [8408.8, 8799.4, 8448.0]     [8552.1, 8552.1, 8552.1]     0
# 58    [9111.0, 10034.4, 9038.5]     [9394.6, 9394.6, 9394.6]     0
# 59    [10251.2, 9167.5, 9637.3]     [9685.3, 9685.3, 9685.3]     0
# 60   [11110.3, 10435.7, 9835.9]  [10460.6, 10460.6, 10460.6]     0
# 61  [10993.8, 10896.7, 10820.5]  [10903.7, 10903.7, 10903.7]     0
#
#     Total Balance  Total Return
# 0         10000.0         0.000
# 1         10146.9         0.015
# 2         10157.3         0.001
# 3         11050.7         0.088
# 4         10659.5        -0.035
# ..            ...           ...
# 57        25656.3         0.015
# 58        28183.9         0.099
# 59        29055.9         0.031
# 60        31381.9         0.080
# 61        32711.0         0.042
#
# [62 rows x 8 columns]
#            Name Start Date   End Date  Start Balance  End Balance      CAGR  \
# 0  Equal Weight 2016-01-29 2026-02-11        10000.0      39264.6  0.145991
#
#    Standard Deviation  Sharpe Ratio  Maximum Drawdown
# 0            0.113551      1.250828         -0.161142
#    Name Start Date   End Date  Start Balance  End Balance     CAGR  \
# 0  GTAA 2016-01-29 2026-02-11        10000.0      32711.0  0.12533
#
#    Standard Deviation  Sharpe Ratio  Maximum Drawdown
# 0            0.136096      1.773415         -0.092771
